# %%
import sys
sys.path.append("src")  # allow imports from src folder

from jupyter_dash import JupyterDash
from dash import html
from inflation_panel import layout as inflation_layout, register_callbacks as inflation_callbacks

app = JupyterDash(__name__, title="US Inflation Dashboard")
app.layout = html.Div([
    html.H2("US Inflation Panel (CPI / Core / PCE)"),
    inflation_layout()
])

# link callbacks
inflation_callbacks(app)

app.run_server(mode="inline", debug=False, port=8051)
# Out:
# c:\Users\gunne\anaconda3\envs\mis20080\Lib\site-packages\dash\dash.py:538: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 17
#      14 # link callbacks
#      15 inflation_callbacks(app)
# ---> 17 app.run_server(mode="inline", debug=False)
#
# File c:\Users\gunne\anaconda3\envs\mis20080\Lib\site-packages\jupyter_dash\jupyter_app.py:339, in JupyterDash.run_server(self, mode, width, height, inline_exceptions, **kwargs)
#     329         url = "http://{host}:{port}".format(
#     330             host=host, port=port, token=JupyterDash._token
#     331         )
#     332         raise OSError(
#     333             "Address '{url}' already in use.\n"
#     334             "    Try passing a different port to run_server.".format(
# ...
